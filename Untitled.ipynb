# %%
import tushare as ts
import pandas as pd

# %%
info = ts.get_stock_basics()
ind = info['industry']

# %%
print(ind.index)
# Out:
# Index(['300504', '603214', '300263', '300341', '300043', '000670', '600602',
#        '603067', '002045', '600136',
#        ...
#        '000950', '000629', '000511', '603897', '603876', '603773', '603733',
#        '603596', '603301', '600806'],
#       dtype='object', name='code', length=3511)

# %%
ind.values
# Out:
# array(['通信设备', '百货', '专用机械', ..., '汽车配件', '医疗保健', '机床制造'], dtype=object)

# %%
type(ind)
# Out:
# pandas.core.series.Series

# %%
a=ind.index

# %%
b=ind.values

# %%
print((a[0]))
# Out:
# 300504

# %%
for i in a:
    print()
# Out:
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ['通信设备' '百货' '专用机械' ... '汽车配件' '医疗保健' '机床制造']
# ...
